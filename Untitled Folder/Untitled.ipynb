# %%
# !pip install tensorflow==2.5.3 opencv-python mediapipe sklearn matplotlib
# Out:
# ...
#   Using cached tensorflow-2.5.3-cp39-cp39-macosx_10_11_x86_64.whl (201.4 MB)
# ...
#      |████████████████████████████████| 2.9 MB 9.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 462 kB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 132 kB 10.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 11.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.6 MB 12.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.7 MB 9.7 MB/s eta 0:00:01
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=e46b9ac46faffe336e518b57a4f81b44c3dbf186018dbc49f0219073a9c495ef
#   Stored in directory: /Users/m1/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
# ...
